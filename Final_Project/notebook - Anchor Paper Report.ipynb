# %% [markdown]
# # Advanced Machine Learning
# # Final project proposal
#
# by
# Tomer Segall, ID301833833
# Millis Sahar, ID300420379

# %% [markdown]
# <br>
#
# <u>Links:</u>
# - Papar: <a href='https://drive.google.com/file/d/1Mm-k9gsPD3U0OH2LxIiXXMYHxlPHYgEv/view?usp=sharing'>tBERT: Topic Models and BERT Joining Forces for Semantic Similarity Detection</a>
# - Paper's <a href='https://github.com/wuningxi/tBERT'>Github</a>
# - <a href='https://colab.research.google.com/drive/1lBtxXNDhlYZy-RoTvecEKRtBhwq2Sk7d?usp=sharing'>Final project proposal</a>
# - <a href='https://colab.research.google.com/drive/1o6hBpZF985yPZA_q0w3KAf7jMreUn12G?usp=sharing'>Anchor Paper Report</a> (this report)
# - <a href='https://colab.research.google.com/drive/1wikoxdlwJrBI972Y4Eg-NJyEzDZ9a6qy?usp=sharing'>Code for Reconstructing The Paper’s Results</a>
# - Apply the paper’s method on a related task - <a href='https://colab.research.google.com/drive/186Rd_-sJVnSslDW6-6RKrs650c_TAEsW?usp=sharing'>Basic Version</a>, <a href='https://colab.research.google.com/drive/1E7_vsbqCFIcBfGbwnQaVrs_5VDrLgNxS?usp=sharing'>Advanced Version</a> (ongoing)
#
# <br>

# %% [markdown]
# <u>Changes which approved by Avrahami:</u>
# - Use only the MSRP dataset
# - Inovative part could include:
#   - `Change the architecture` to input one sentence instead of two.
#   - `Different Tasks` - Fake News classification, Sentiment Analysis, etc.
#   - `Augmentation` of the dataset
#   - `Change Encoder` - distilbert, ALMO, RoBERTa, etc.
#
#
# <br>

# %% [markdown]
# # Anchor paper
#
# <br>
#
# ### State the anchor paper
# As mentioned before, Our research will be based on the article <a href='https://aclanthology.org/2020.acl-main.630.pdf'>"tBERT: Topic Models and BERT Joining Forces for Semantic Similarity Detection"</a> and this is its <a href='https://github.com/wuningxi/tBERT'>code</a>.
#
# <br>
#
# ### Provide a very short summary of the paper
# They propose a novel topic-informed BERT-based architecture for pairwise **semantic similarity** detection and show that their model improves performance over strong neural baselines across a variety of English language datasets.
# They also find that the addition of topics to BERT helps particularly with resolving domain-specific cases.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### What is the main objective of the paper, what are they trying to solve?
#
# Semantic similarity detection is a fundamental task in natural language understanding(NLP).
# Adding topic information has been useful for previous feature-engineered semantic similarity models as well as neural models for other tasks.
#
# There is currently no standard way of combining topics with pretrained contextual representations such as BERT. The paper investigates if topic models can further improve BERT's performance for semantic similarity detection. The objective is to show that combining topic information with BERT improves performance over various datasets.
#
# <br><br><br>

# %% [markdown]
# # Reconstruct and Run the Paper's Code

# %% [markdown]
# The code is build on pure TensorFlow. And sue to it's complexity we did not managed to run it on colab. But we were able to run it on our local machine.
# And here is some screen shots while running it with it's defulat values on the MSRP dataset.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Final accuracy score of 0.82, with 59 minutes of training.**
# <br><br><br>

# %% [markdown]
# # Reconstruct and Run on our code version

# %% [markdown]
# <a href='https://colab.research.google.com/drive/1wikoxdlwJrBI972Y4Eg-NJyEzDZ9a6qy?usp=sharing'>Our code</a> version used Torch framework to create the same method suggested by the paper while the code and training process were mush **easier, faster, and more explainable.**

# %% [markdown]
# <br>
# Due to the article's lack of information regarding all parameters we had to use hyper parameter tuning to mimic the article's results.
#
# <br><br>
#
# **Parameters that were mentioned:**
# - Batch size = 32
# - Epochs number = 3
# - Loss function = binary cross entropy
# - Preffered topics number in range of 70-90
#
# <br>
#
# **Parameters that were not mentioned:**
# - Optimizer
# - Random Seeds
# - Learning rate
# - Classification Layers Specs
#
# (We were not able to extract these from their code, due to complexity and "spaghetti code")
#
# <br><br>
#
# We needed to run a big number of trial and error to find the optimal hyper-params.
#
# After that, using this hyper-params, we tried to fing the optimal number of topics (t=...) for the LDA in tBERT.
#
# This plots shows the training process and the accuracy results for the test data:
#
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# we can see the model using a **topic number of 90** were able to **achieve the Accuracy score of the article.**

# %% [markdown]
# # Apply Method on a Related Task

# %% [markdown]
# As discussed with Avrahami and approved by him,
# we are still in the process of applying the tBERT concept on related tasks.
#
# Our firsts attempts were promising!
# And did show an advantage for tBERT.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# But they did not achieve `State of the Art` performences/results.
# So this is still an **ongoing research** that we will explore in the inovative part of our work.
#
# <br><br><br>

# %% [markdown]
# # Further Work

# %% [markdown]
# Following Avrahami's instructions,
# we will use the tBERT concept to prove that using an additinal information from LDA will benefit a variety of tasks.
# While simultaneously use advanced NLP teqniqusts and models as mentioned above (augmentation, change encoder, etc).

# %% [markdown]
# <br><br><br>
# Thanks for reading...
