# %% [markdown]
# ### Insperational works:
#
# https://www.kaggle.com/hiroshi20180410/cord19-semantic-search-engine-for-taskid583
#
# https://www.kaggle.com/sandyvarma/covid-19-bert-mesh-enabled-knowledge-grap
#
# https://www.kaggle.com/dirktheeng/anserini-bert-squad-for-semantic-corpus-search
#
# https://towardsdatascience.com/bert-explained-state-of-the-art-language-model-for-nlp-f8b21a9b6270 - BERT simple explanation
#
# https://www.analyticsvidhya.com/blog/2020/08/top-4-sentence-embedding-techniques-using-python/ - reference for BERT usage
#
#
# Doc2Vec
# https://www.kaggle.com/luisblanche/cord-19-use-doc2vec-to-match-articles-to-tasks
#
# Taboola - article similarity
# https://www.youtube.com/watch?v=EvANtuUbWc4&ab_channel=TaboolaEngineering
